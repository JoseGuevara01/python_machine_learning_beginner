# %%
import quandl
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime 

from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.linear_model import LinearRegression

quandl.ApiConfig.api_key = '5XGFKaEQy8-J2SUh8uAU'

df = quandl.get('WIKI/AMZN')
df = df[['Adj. Close']]
df
# Out:
#              Adj. Close
# Date
# 1997-05-16     1.729167
# 1997-05-19     1.708333
# 1997-05-20     1.635833
# 1997-05-21     1.427500
# 1997-05-22     1.395833
# ...                 ...
# 2018-03-21  1581.860000
# 2018-03-22  1544.100000
# 2018-03-23  1495.560000
# 2018-03-26  1555.860000
# 2018-03-27  1497.050000
#
# [5248 rows x 1 columns]

# %%
df['Adj. Close'].plot(figsize=(15,6),color='b')
plt.legend(loc='upper left')
plt.show()

# %%
forecast = 30
df['Prediction'] = df[["Adj. Close"]].shift(-forecast)

x = np.array(df.drop(['Prediction'],1))
x = preprocessing.scale(x)

x_forecast = x[-forecast:]
x = x[:-forecast]

y = np.array(df['Prediction'])
y = y[:-forecast]

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

clf = LinearRegression()
clf.fit(X_train, y_train)

confidence = clf.score(X_test, y_test)

forecast_predicted = clf.predict(x_forecast)
forecast_predicted

plt.plot(x, y)

import datetime
dates= pd.date_range(start='2018-03-28', end='2018-04-26')
plt.plot(dates, forecast_predicted, color='y')
df['Adj. Close'].plot(color='r')
plt.xlim(xmin=datetime.date(2017,4,26))
# Out:
# /var/folders/dd/b94n5r2s3pgcycnxdlzv69p80000gn/T/ipykernel_27737/879892280.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   x = np.array(df.drop(['Prediction'],1))
# (17282.0, 18529.385511200544)
